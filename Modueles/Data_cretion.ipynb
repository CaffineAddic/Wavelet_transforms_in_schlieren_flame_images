# %%
import os
import numpy as np

# %%
#location with the images

loc_P04 = '/home/saumya/Documents/Flame-diagonis-Dip/Schlieren-Data/P04/'

#location where you want the numpy files to be

loc_P10 = '/home/saumya/Documents/Flame-diagonis-Dip/Schlieren-Data/P04/'

# %%
#Name of the numpy file for data

name = "Name"

# %% [markdown]
# ## Remember to keep the location as a string ending with /
# #### for example '/home/Saumya/code/P1/'

# %%
files = os.listdir(loc_P04)

# %%
import imageio as iio
import matplotlib.pyplot as plt
from skimage.color import rgb2gray

# %%
files
# Out:
# ['001.jpg',
#  '002.jpg',
#  '003.jpg',
#  '004.jpg',
#  '005.jpg',
#  '006.jpg',
#  '007.jpg',
#  '008.jpg',
#  '009.jpg',
#  '010.jpg',
#  '011.jpg',
#  '012.jpg',
#  '013.jpg',
#  '014.jpg',
#  '015.jpg',
#  '016.jpg',
#  '017.jpg',
#  '018.jpg',
#  '019.jpg',
#  '020.jpg',
#  '021.jpg',
#  '022.jpg',
#  '023.jpg',
#  '024.jpg',
#  '025.jpg',
#  '026.jpg',
#  '027.jpg',
#  '028.jpg',
#  '029.jpg',
#  '030.jpg',
#  '031.jpg',
#  '032.jpg',
#  '033.jpg',
#  '034.jpg',
#  '035.jpg',
#  '036.jpg',
#  '037.jpg',
#  '038.jpg',
#  '039.jpg',
#  '040.jpg',
#  '041.jpg',
#  '042.jpg',
#  '043.jpg',
#  '044.jpg',
#  '045.jpg',
#  '046.jpg',
#  '047.jpg',
#  '048.jpg',
#  '049.jpg',
#  '050.jpg',
#  '051.jpg',
#  '052.jpg',
#  '053.jpg',
#  '054.jpg',
#  '055.jpg',
#  '056.jpg',
#  '057.jpg',
#  '058.jpg',
#  '059.jpg',
#  '060.jpg',
#  '061.jpg',
#  '062.jpg',
#  '063.jpg',
#  '064.jpg',
#  '065.jpg',
#  '066.jpg',
#  '067.jpg',
#  '068.jpg',
#  '069.jpg',
#  '070.jpg',
#  '071.jpg',
# ...

# %% [markdown]
# ## ^^^  if you see images name above they have been read

# %%
a = iio.imread(loc_P04+files[100])
plt.imshow(a)
# Out:
# /tmp/ipykernel_591429/678853104.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   a = iio.imread(loc_P04+files[100])

# %%
p10 = []
for i in files:
    a = iio.imread(loc_P04+i)
    b = np.array(a[100:-10,775:1350])
    b = (rgb2gray(b)*255).astype(np.uint8)
    # np.save(loc_P10+i, b)
    # iio.mimwrite(loc_P04_crop+i, b)
    p10.append(b)
p10 = np.array(p10)

# %%
np.save(loc_P04+name, p10)
