# %%
# import glob 
import os
import numpy as np
import cv2

# %%
loc_P04 = '/home/saumya/Documents/Schileren_wavelet/Schlieren-Data/German_data/cl19340rcch006/'

# %%
files = os.listdir(loc_P04)

# %%
import imageio as iio

# %%
p10 = []
for i in files:
    p10.append(iio.imread(loc_P04+i))
# Out:
# /tmp/ipykernel_26630/3112594909.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   p10.append(iio.imread(loc_P04+i))

# %%
p10 = np.array(p10)

# %%
p10.shape
# Out:
# (8192, 521, 524, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(p10[0])

# %%
# plt.imshow(p10[100][260:950, 250:750])

# %%
p10[:,:,:,1].shape
# Out:
# (8192, 521, 524)

# %%
np.save(loc_P04+'cl19340rcch006',p10[:,:,:,1])
