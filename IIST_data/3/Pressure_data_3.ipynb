# %%
import numpy as np
from scipy.fft import fft, fftfreq
import os

# %%
loc = '/home/saumya/Documents/Flame-diagonis-Dip/Schlieren-Data/Q200-p09/'

# %%
files = os.listdir(loc)

# %%
files
# Out:
# ['008-pq.xlsx',
#  '009-pq.xlsx',
#  '010-pq.xlsx',
#  '011-pq.xlsx',
#  '013-pq.xlsx',
#  'r2sc006-008pq',
#  'r2sc007-009pq',
#  'r2sc008-010pq',
#  'r2sc009-011pq',
#  'r2sc010-013pq']

# %%
import pandas as pd

# %%
df = pd.read_excel(loc+files[2])

# %%
df.head()
# Out:
#       time    comb (p)    HR (q)  Unnamed: 3  S3
# 0  0.00000   46.654853 -0.006734         NaN NaN
# 1  0.00005   78.854463 -0.006861         NaN NaN
# 2  0.00010   90.929317 -0.006952         NaN NaN
# 3  0.00015  105.687471 -0.007345         NaN NaN
# 4  0.00020  113.737374 -0.007237         NaN NaN

# %%
dat = df.to_numpy()

# %%
import matplotlib.pyplot as plt

# %%
file = dat[:,1].astype(np.float32)

# %%
file.shape
# Out:
# (200000,)

# %%
fft_sig = fft(file)

# %%
n = file.shape[0]  # Number of data points
sampling_rate = 20 * 1000 # Adjust this if your data is sampled differently
frequencies = np.fft.fftfreq(n, d=1/sampling_rate)

# %%
plt.plot(frequencies, abs(fft_sig))

# %%
plt.plot(frequencies, abs(fft_sig))
plt.xlim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
plt.plot(frequencies, abs(fft_sig))
plt.xlim(80, 140)
# Out:
# (80.0, 140.0)
