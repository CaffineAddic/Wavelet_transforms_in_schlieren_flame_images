# %%
# import glob 
import os
import numpy as np
# import cv2

# %%
loc_P04 = '/home/saumya/Documents/Flame-diagonis-Dip/Schlieren-Data/Q200-p09/r2sc009-011pq/'

# %%
files = os.listdir(loc_P04)

# %%
import imageio as iio

# %%
p10 = []
for i in files:
    p10.append(iio.imread(loc_P04+i))
# Out:
# /tmp/ipykernel_26099/3112594909.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   p10.append(iio.imread(loc_P04+i))

# %%
p10 = np.array(p10)

# %%
p10.shape
# Out:
# (3046, 480, 768)

# %%
import matplotlib.pyplot as plt

# %%
# 250, 950: 250:650

# %%
plt.imshow(p10[0])

# %%
plt.imshow(p10[10][170:385, 70:390])

# %%
p10.dtype
# Out:
# dtype('uint8')

# %%
np.save(loc_P04+'P10',p10)
