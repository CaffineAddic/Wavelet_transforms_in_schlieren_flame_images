# %%
# import glob 
import os
import numpy as np
# import cv2

# %%
loc_P04 = '/home/saumya/Documents/Flame-diagonis-Dip/Schlieren-Data/Firepit/SURYA_CineF11/'

# %%
files = os.listdir(loc_P04)

# %%
import imageio as iio
import matplotlib.pyplot as plt

# %%
a = iio.imread(loc_P04+files[100])
# Out:
# /tmp/ipykernel_64327/1377894387.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   a = iio.imread(loc_P04+files[100])

# %%
plt.imshow(a[100:-10,775:1350])

# %%
p10 = []
for i in files:
    a = iio.imread(loc_P04+i)
    b = a[500:-10, 1050:1225]
    b.shape
    # iio.mimwrite(loc_P04_crop+i, b)
    p10.append(b)
# Out:
# /tmp/ipykernel_64327/1090944026.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   a = iio.imread(loc_P04+i)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/saumya/Documents/Flame-diagonis-Dip/Wavelet_transforms_in_schlieren_flame_images/Firepit/Reader.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/home/saumya/Documents/Flame-diagonis-Dip/Wavelet_transforms_in_schlieren_flame_images/Firepit/Reader.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> p10 = []
#       <a href='vscode-notebook-cell:/home/saumya/Documents/Flame-diagonis-Dip/Wavelet_transforms_in_schlieren_flame_images/Firepit/Reader.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> for i in files:
# ----> <a href='vscode-notebook-cell:/home/saumya/Documents/Flame-diagonis-Dip/Wavelet_transforms_in_schlieren_flame_images/Firepit/Reader.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     a = iio.imread(loc_P04+i)
#       <a href='vscode-notebook-cell:/home/saumya/Documents/Flame-diagonis-Dip/Wavelet_transforms_in_schlieren_flame_images/Firepit/Reader.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     b = a[500:-10, 1050:1225]
#       <a href='vscode-notebook-cell:/home/saumya/Documents/Flame-diagonis-Dip/Wavelet_transforms_in_schlieren_flame_images/Firepit/Reader.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     b.shape
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/imageio/__init__.py:97, in imread(uri, format, **kwargs)
#      68 """imread(uri, format=None, **kwargs)
#      69
#      70 Reads an image from the specified file. Returns a numpy array, which
#    (...)
#      86     to see what arguments are available for a particular format.
#      87 """
#      89 warnings.warn(
#      90     "Starting with ImageIO v3 the behavior of this function will switch to that of"
#      91     " iio.v3.imread. To keep the current behavior (and make this warning disappear)"
#    (...)
#      94     stacklevel=2,
#      95 )
# ---> 97 return imread_v2(uri, format=format, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/imageio/v2.py:360, in imread(uri, format, **kwargs)
#     357 imopen_args["legacy_mode"] = True
#     359 with imopen(uri, "ri", **imopen_args) as file:
# --> 360     result = file.read(index=0, **kwargs)
#     362 return result
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/imageio/plugins/pillow.py:239, in PillowPlugin.read(self, index, mode, rotate, apply_gamma, writeable_output, pilmode, exifrotate, as_gray)
#     236 if isinstance(index, int):
#     237     # will raise IO error if index >= number of frames in image
#     238     self._image.seek(index)
# --> 239     image = self._apply_transforms(
#     240         self._image, mode, rotate, apply_gamma, writeable_output
#     241     )
#     242 else:
#     243     iterator = self.iter(
#     244         mode=mode,
#     245         rotate=rotate,
#     246         apply_gamma=apply_gamma,
#     247         writeable_output=writeable_output,
#     248     )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/imageio/plugins/pillow.py:339, in PillowPlugin._apply_transforms(self, image, mode, rotate, apply_gamma, writeable_output)
#     336     image = np.round(image).astype(np.uint8)
#     338 if writeable_output and not image.flags["WRITEABLE"]:
# --> 339     image = np.array(image)
#     341 return image
#
# KeyboardInterrupt:

# %%
p10 = np.array(p10)

# %%
p10.shape
# Out:
# (3112, 210, 175, 3)

# %%
250, 950: 250:650

# %%
plt.imshow(p10[0])

# %%
# plt.imshow(p10[100][260:950, 250:750])

# %%
np.save(loc_P04+'P10',p10)
