# %%
# import glob 
import os
import numpy as np
# import cv2

# %%
loc_P04 = '/home/saumya/Documents/Schileren_wavelet/Schlieren-Data/Firepit/SURYA_CineF11/'
loc_P10 = '/home/saumya/Documents/Schileren_wavelet/Schlieren-Data/Firepit/SURYA_CineF11_np/'

# %%
files = os.listdir(loc_P04)

# %%
np.uint8
# Out:
# numpy.uint8

# %%
import imageio as iio
import matplotlib.pyplot as plt
from skimage.color import rgb2gray

# %%
a = iio.imread(loc_P04+files[100])
# Out:
# /tmp/ipykernel_14309/1377894387.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   a = iio.imread(loc_P04+files[100])

# %%
a.shape
# Out:
# (720, 2048, 3)

# %%
plt.imshow(a[100:-10,775:1350])

# %%
p10 = []
for i in files:
    a = iio.imread(loc_P04+i)
    b = np.array(a[100:-10,775:1350])
    b = (rgb2gray(b)*255).astype(np.uint8)
    # np.save(loc_P10+i, b)
    # iio.mimwrite(loc_P04_crop+i, b)
    p10.append(b)
# Out:
# /tmp/ipykernel_14309/2189105763.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   a = iio.imread(loc_P04+i)

# %%
files1 = os.listdir(loc_P10)

# %%
# p10 = []

# for k in files1:
#     k = np.load(loc_P10+k)
#     p10.append(k)

# %%
p10 = np.array(p10)

# %%
np.int8
# Out:
# numpy.int8

# %%
plt.imshow(p10[0])

# %%
# plt.imshow(p10[100][260:950, 250:750])

# %%
np.save(loc_P04+'Gray_data',p10)
